# %% [markdown]
# # Testing how images display on github using different embeddings

# %% [markdown]
# <div>
#    <img src="images/Deep_Learning_W_Diffusion/Diffusion_Forward.png" width=800>
# </div>
#
# ![title](images/Deep_Learning_W_Diffusion/Diffusion_Forward.png)

# %%
from IPython.display import Image
Image("images/Deep_Learning_W_Diffusion/Diffusion_Forward.png")

# %%
# %%html
# <img src="images/Deep_Learning_W_Diffusion/Diffusion_Forward.png", width=600, height=400>
# Out:
# <img src="images/Deep_Learning_W_Diffusion/Diffusion_Forward.png", width=600, height=400>
